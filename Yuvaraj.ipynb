# %%
print("                           WELCOME TO BUDGET CALCULATOR                          ")
a = int(input("ENTER YOUR BUDGET =  "))
b = int(input("ENTER THE AMOUNT YOU WANT TO SAVE  =   "))#savings from his income which is fixed.

c = a - b # I decleared a varaible "c" which tells the budget he can spend for his needs and wants.

print("  AMOUNT OF EXPENDITURE ON NEEDS & WANTS  =    ",  c)
if (a >= b):#It verfies whether your savings amount is greater than budget.
    need = []
    priority = []
    price = []
    d = int(input("******************* HOW MANY ITEMS DO YOU NEEDS AND WANTS FOR THIS MONTH************ = "))
    # the above vairable "d" is used to take the items you need for this month.
    print("WHAT IS THE NAME FOR ITEM 1")
    for i in range(0, d):# I used a for loop which helps to ask the details of item name,price,priority. 
        x = str(input(""))
        print("ENTER THE PRICE OF THE ITEM ", x.upper())#to convert lower case to upper case letters. 
        e1 = int(input(""))
        print("ENTER THE PRIORITY TO THE ABOVE ITEM ($-$ 1 has the most priority and you can use it once and if you want you give 2 as priority$-$0 )")
        f = int(input(""))
        print("ENTER NAME OF", i + 2, "ITEM")
        if (i < d):
            need.append(x)#this three lines of code will append the details to there respective lists which i created at line 7-9.
            priority.append(f)
            price.append(e1)
            lis_A = (dict(zip(priority,price)))#I created a dictionary with 2 lists priority and price using "zip".
            lis_B=(dict(zip(priority,need)))#I created a dictionary with 2 lists priority and need using "zip".
            dicto={}#I created a dicto dictionary which sorts the lis_A using "priority" as key.
        for i in sorted(lis_A.keys()):
            dicto[i] = lis_A[i]
            dicto1={}#I created a dicto dictionary which sorts the lis_B using "priority" as key.
        for i in sorted(lis_B.keys()):
            dicto1[i] = lis_B[i]
    j = 0
    g = 0
    for i in range(0, len(price)):#lines 32-38 helps us to tell the sum of price given to the items using a for loop. 
        h = price[i]
        j = j + h
    g = j #I created a vairable which tells the sum of cost .
    print("SUM OF YOUR NEEDS FOR THIS MONTH ", g)
    def budget_checker(g,c,need,price,priority,dicto,lis_A,lis_B,dicto1):
        if (g <= c):#I kept a condition which helps us ,if g is less than c that means if the sum of cost of items is less than the given budget to utlize. 
            print(" $$$$$ HURRAY YOU CAN BUY ALL YOUR NEEDS & WANTS FROM YOUR BUDGET AFTER SAVINGS $$$$")
            for i in range(0, len(price)):
                print(need[i])
            m = c - g#please check 46th line
            n = b + m#It tells that how much money is saved and saved money is transferd to savings money 
            print(lis_A)
            print(lis_B)
            print(" YOUR TOTAL SAVINGS ON NEEDS FOR THIS MONTH             =", m)
            print(" YOUR TOTAL SAVINGS AFTER NEEDS AND ADDED TO ORGINAL SAVINGS FOR THIS MONTH             =", n)
            print("****DOWN BELOW YOU CAN CHECK THE SORTED DICTIONARY CONSITS NAME AND PRICE WITH PRIORITY***** ")
            print(dicto)
            print(dicto1)
        else:
            listx=[]
            while (g > c):##I kept a condition which helps us ,if g is greater than c that means if the sum of cost of items is greater than the given budget to utlize. 
                v=sorted(dicto.keys()).pop()#It sorts the dicitonar dicto using priority as keys and remove the last item.
                del dicto[v]#I used del to remove from dicto
                sum=0
                for i in range(0,10):#The lines 58-61 checks the sum of cost given to the item is less than the budget.
                    if i in dicto.keys():
                        sum += dicto[i]
                        
                g=sum
                
                for i in dicto.keys():#Using the above 58-61 line I got the value of key so I took the values from dicto1 
                     listx.append(dicto1[i])        
            print( '---------------------------------------------------------------------------------')
            print('THIS THE TOTAL SUM OF ITEMS YOU CAN BUY FROM YOUR BUDGET ACCORDING TO PRIORITY  =')
            print("               ",sum,"              ") 
            print("THE ITEMS BELOW CAN ONLY BE BOUGHT FROM THE BUDGET GIVEN =         ")
            print("             " , listx,"             ")
            
budget_checker(g,c,need,price,priority,dicto,lis_A,lis_B,dicto1)
# Out:
#                            WELCOME TO BUDGET CALCULATOR
# ENTER YOUR BUDGET =  2000
# ENTER THE AMOUNT YOU WANT TO SAVE  =   800
#   AMOUNT OF EXPENDITURE ON NEEDS & WANTS  =     1200
# ******************* HOW MANY ITEMS DO YOU NEEDS AND WANTS FOR THIS MONTH************ = 3
# WHAT IS THE NAME FOR ITEM 1
# A
# ENTER THE PRICE OF THE ITEM  A
# 200
# ENTER THE PRIORITY TO THE ABOVE ITEM ($-$ 1 has the most priority and you can use it once and if you want you give 2 as priority$-$0 )
# 1
# ENTER NAME OF 2 ITEM
# B
# ENTER THE PRICE OF THE ITEM  B
# 300
# ENTER THE PRIORITY TO THE ABOVE ITEM ($-$ 1 has the most priority and you can use it once and if you want you give 2 as priority$-$0 )
# 3
# ENTER NAME OF 3 ITEM
# C
# ENTER THE PRICE OF THE ITEM  C
# 500
# ENTER THE PRIORITY TO THE ABOVE ITEM ($-$ 1 has the most priority and you can use it once and if you want you give 2 as priority$-$0 )
# 9
# ENTER NAME OF 4 ITEM
# SUM OF YOUR NEEDS FOR THIS MONTH  1000
# ...
